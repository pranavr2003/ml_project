# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Displaying the dataset

data = pd.read_csv('online_news_pop/OnlineNewsPopularity.csv')
data.head()
# Out:
#                                                  url   timedelta
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0  \
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words
# 0             12.0              219.0          0.663594                1.0  \
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...
# ...

# %%
names_file = open('online_news_pop/OnlineNewsPopularity.names', 'r')
names = names_file.read()
# names

# %%
# From names, read only the attribute names and store them in a list

names_list = names.split('\n')
names_list = names_list[41:111]
names_list = [name.split(':')[0] for name in names_list]

# names_list[i][8:] is the name of the (i+1)th attribute, starting 
# with the serial number and omitting the space before that

# %%
# Removing the unrequired spaces and serial numbers from the attribute names

names_list2 = [name for name in names_list if name.startswith('                                       ') == False]

len(names_list2)

for name, i in zip(names_list2, range(len(names_list2))):
    names_list2[i] = name[8:]

names_list2
# Out:
# ['url',
#  'timedelta',
#  'n_tokens_title',
#  'n_tokens_content',
#  'n_unique_tokens',
#  'n_non_stop_words',
#  'n_non_stop_unique_tokens',
#  'num_hrefs',
#  'num_self_hrefs',
#  'num_imgs',
#  'num_videos',
#  'average_token_length',
#  'num_keywords',
#  'data_channel_is_lifestyle',
#  'data_channel_is_entertainment',
#  'data_channel_is_bus',
#  'data_channel_is_socmed',
#  'data_channel_is_tech',
#  'data_channel_is_world',
#  'kw_min_min',
#  'kw_max_min',
#  'kw_avg_min',
#  'kw_min_max',
#  'kw_max_max',
#  'kw_avg_max',
#  'kw_min_avg',
#  'kw_max_avg',
#  'kw_avg_avg',
#  'self_reference_min_shares',
#  'self_reference_max_shares',
#  'self_reference_avg_sharess',
#  'weekday_is_monday',
#  'weekday_is_tuesday',
#  'weekday_is_wednesday',
#  'weekday_is_thursday',
#  'weekday_is_friday',
#  'weekday_is_saturday',
#  'weekday_is_sunday',
#  'is_weekend',
#  'LDA_00',
#  'LDA_01',
#  'LDA_02',
#  'LDA_03',
#  'LDA_04',
#  'global_subjectivity',
# ...
